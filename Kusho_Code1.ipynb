# %% [markdown]
# <a href="https://colab.research.google.com/github/TusharPaul01/Work/blob/main/Kusho_Code1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/transformers.git@main accelerate
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git (to revision main) to /tmp/pip-req-build-kmsp26e_
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-kmsp26e_
#   Resolved https://github.com/huggingface/transformers.git to commit 6b7f8ff1f3db0b21afbedb322770c292bc8dedae
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 101.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.4 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer,pipeline
import transformers
import torch

# %%
model = "codellama/CodeLlama-13b-Instruct-hf"

# %%
tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ...

# %%
#error_code = input("Enter Error Code: ")
#system = "API Key information " + error_code
system = "English expert .Provide answers in English"
#user_input ="write a python code that creates text to speech"
user_input ="write a poem"
#user_input = input("Enter")

#user_input1 = """def add_even_numbers(a, b):
    #if a % 2 == 0 and b % 2 == 0:"""

prompt = f"<s><<SYS>>\n{system}\n<</SYS>>\n\n{user_input}"

# %%
sequences = pipeline(
    prompt,
    do_sample=True,
    top_k=10,
    temperature=0.1,
    top_p=0.95,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=200,
    add_special_tokens=False
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.

# %%
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: <s><<SYS>>
# English expert .Provide answers in English
# <</SYS>>
#
# write a poem about the beauty of nature
#
# The beauty of nature is a sight to behold
#
# The trees sway gently in the breeze
#
# The flowers bloom in every color of the rainbow
#
# The birds sing sweet melodies
#
# The sun shines bright and warm
#
# The moon glows softly in the night
#
# The beauty of nature is a gift from above
#
# It brings us joy and peace
#
# It reminds us of the beauty of life
#
# It is a treasure that we must cherish and protect
#
# The beauty of nature is a treasure that we must cherish and protect
#
# It is a treasure that we must cherish and protect
#
# It is a treasure that we must cherish and protect
#
# It is a treasure that we must cherish
